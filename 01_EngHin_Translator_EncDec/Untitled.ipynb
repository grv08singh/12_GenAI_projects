# %%
import tensorflow as tf
import intel_extension_for_tensorflow as itex

# This prevents TensorFlow from hogging all the GPU memory at once
gpus = tf.config.list_physical_devices('XPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("XPU Memory Growth Enabled")
    except RuntimeError as e:
        print(e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import tensorflow as tf
# ----> 2 import intel_extension_for_tensorflow as itex
#       4 # This prevents TensorFlow from hogging all the GPU memory at once
#       5 gpus = tf.config.list_physical_devices('XPU')
#
# ModuleNotFoundError: No module named 'intel_extension_for_tensorflow'

# %%
tf.config.list_physical_devices('XPU')
# Out:
# []
